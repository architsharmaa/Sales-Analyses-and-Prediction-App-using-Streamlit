# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
from pandas.api.types import CategoricalDtype
import calendar
import numpy as np

# %% [markdown]
# ## Importing dataset
#
# train.csv - historical data including Sales
# <br>
# store.csv - supplemental information about the stores

# %%
df_train = pd.read_csv(r"D:\Devansh\ML\Datasets\Rossman_Store_Sales(Regression)\train.csv")
df_store = pd.read_csv(r"D:\Devansh\ML\Datasets\Rossman_Store_Sales(Regression)\store.csv")

# %% [markdown]
# ## Cleansing dataset

# %%
# appliyng left join 
df_new = df_train.merge(df_store,how='left')

# narrowing dataset[2013-15] to 2014 
df_new = df_new.iloc[236380:610234,:]

# adding DayofWeekName for better graph-labeling 
dayOfWeek={1:'Monday', 2:'Tuesday', 3:'Wednesday', 4:'Thursday', 5:'Friday', 6:'Saturday', 7:'Sunday'}
df_final['DayOfWeekName'] = df_final['DayOfWeek'].map(dayOfWeek)
df_final = df_final[['Store', 'DayOfWeek', 'DayOfWeekName', 'Date', 'Sales', 'Customers',
       'Open', 'Promo', 'StateHoliday', 'SchoolHoliday', ]]

# adding MonthName
pd.DatetimeIndex(df_new['Date']).month
df_final.insert(4, 'MonthName', pd.DataFrame([int(df_new['Date'][i][5:7]) for i in df.index]))
df_final['MonthName'] = df_final['MonthName'].apply(lambda x: calendar.month_abbr[x])

# splitting dataset into quarters and saving to CSVs
q1 = df_final.iloc[:100350,:]
q2 = df_final.iloc[100350:201815,:]
q3 = df_final.iloc[201815:287835,:]
q4 = df_final.iloc[287835:,:]

q1.to_csv(r"D:\Devansh\ML\Datasets\Rossman_Store_Sales(Regression)\quarters\q1.csv", index= False)
q2.to_csv(r"D:\Devansh\ML\Datasets\Rossman_Store_Sales(Regression)\quarters\q2.csv", index= False)
q3.to_csv(r"D:\Devansh\ML\Datasets\Rossman_Store_Sales(Regression)\quarters\q3.csv", index= False)
q4.to_csv(r"D:\Devansh\ML\Datasets\Rossman_Store_Sales(Regression)\quarters\q4.csv", index= False)

# Ordering Week Day & Month Labels
WeekDayLabels = ['Monday','Tuesday','Wednesday','Thursday','Friday', 'Saturday', 'Sunday']
M_catType = CategoricalDtype(categories = WeekDayLabels, ordered = True)
q1['DayOfWeekName'] = q1['DayOfWeekName'].astype(M_catType)
q2['DayOfWeekName'] = q2['DayOfWeekName'].astype(M_catType)
q3['DayOfWeekName'] = q3['DayOfWeekName'].astype(M_catType)
q4['DayOfWeekName'] = q4['DayOfWeekName'].astype(M_catType)

MonthLabels = ['Jan','Feb','Mar','Apr','May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
M_catType = CategoricalDtype(categories = MonthLabels, ordered = True)
q1['MonthName'] = q1['MonthName'].astype(M_catType)
q2['MonthName'] = q2['MonthName'].astype(M_catType)
q3['MonthName'] = q3['MonthName'].astype(M_catType)
q4['MonthName'] = q4['MonthName'].astype(M_catType)

# %%
df_final
# Out:
#         Store  DayOfWeek DayOfWeekName        Date MonthName  Sales  \
# 0        1115          3     Wednesday  2014-01-01       Jan      0
# 1        1114          3     Wednesday  2014-01-01       Jan      0
# 2        1113          3     Wednesday  2014-01-01       Jan      0
# 3        1112          3     Wednesday  2014-01-01       Jan      0
# 4        1111          3     Wednesday  2014-01-01       Jan      0
# 5        1110          3     Wednesday  2014-01-01       Jan      0
# 6        1109          3     Wednesday  2014-01-01       Jan      0
# 7        1108          3     Wednesday  2014-01-01       Jan      0
# 8        1107          3     Wednesday  2014-01-01       Jan      0
# 9        1106          3     Wednesday  2014-01-01       Jan      0
# 10       1105          3     Wednesday  2014-01-01       Jan      0
# 11       1104          3     Wednesday  2014-01-01       Jan      0
# 12       1103          3     Wednesday  2014-01-01       Jan      0
# 13       1102          3     Wednesday  2014-01-01       Jan      0
# 14       1101          3     Wednesday  2014-01-01       Jan      0
# 15       1100          3     Wednesday  2014-01-01       Jan      0
# 16       1099          3     Wednesday  2014-01-01       Jan      0
# 17       1098          3     Wednesday  2014-01-01       Jan      0
# 18       1097          3     Wednesday  2014-01-01       Jan   7016
# 19       1096          3     Wednesday  2014-01-01       Jan      0
# 20       1095          3     Wednesday  2014-01-01       Jan      0
# 21       1094          3     Wednesday  2014-01-01       Jan      0
# 22       1093          3     Wednesday  2014-01-01       Jan      0
# 23       1092          3     Wednesday  2014-01-01       Jan      0
# 24       1091          3     Wednesday  2014-01-01       Jan      0
# 25       1090          3     Wednesday  2014-01-01       Jan      0
# 26       1089          3     Wednesday  2014-01-01       Jan      0
# 27       1088          3     Wednesday  2014-01-01       Jan      0
# 28       1087          3     Wednesday  2014-01-01       Jan      0
# 29       1086          3     Wednesday  2014-01-01       Jan      0
# ...       ...        ...           ...         ...       ...    ...
# 372914     34          3     Wednesday  2014-12-31       Dec   5096
# 372915     33          3     Wednesday  2014-12-31       Dec   6969
# 372916     31          3     Wednesday  2014-12-31       Dec   3150
# 372917     30          3     Wednesday  2014-12-31       Dec   2257
# 372918     29          3     Wednesday  2014-12-31       Dec   4890
# 372919     28          3     Wednesday  2014-12-31       Dec   1713
# 372920     27          3     Wednesday  2014-12-31       Dec   5385
# 372921     26          3     Wednesday  2014-12-31       Dec   2891
# 372922     25          3     Wednesday  2014-12-31       Dec   7771
# 372923     24          3     Wednesday  2014-12-31       Dec   7503
# 372924     23          3     Wednesday  2014-12-31       Dec   3489
# 372925     21          3     Wednesday  2014-12-31       Dec   3043
# 372926     19          3     Wednesday  2014-12-31       Dec   3772
# 372927     18          3     Wednesday  2014-12-31       Dec   4286
# 372928     17          3     Wednesday  2014-12-31       Dec   2639
# 372929     16          3     Wednesday  2014-12-31       Dec   4720
# 372930     15          3     Wednesday  2014-12-31       Dec   4291
# 372931     14          3     Wednesday  2014-12-31       Dec   3939
# 372932     12          3     Wednesday  2014-12-31       Dec   4871
# 372933     11          3     Wednesday  2014-12-31       Dec   3838
# 372934     10          3     Wednesday  2014-12-31       Dec   4216
# 372935      9          3     Wednesday  2014-12-31       Dec   5063
# 372936      8          3     Wednesday  2014-12-31       Dec   3025
# 372937      7          3     Wednesday  2014-12-31       Dec   5219
# 372938      6          3     Wednesday  2014-12-31       Dec   2604
# 372939      5          3     Wednesday  2014-12-31       Dec   1830
# 372940      4          3     Wednesday  2014-12-31       Dec  10152
# 372941      3          3     Wednesday  2014-12-31       Dec   3804
# 372942      2          3     Wednesday  2014-12-31       Dec   2269
# 372943      1          3     Wednesday  2014-12-31       Dec   2605
#
#         Customers  Open  Promo StateHoliday  SchoolHoliday StoreType  \
# 0               0     0      0            a              1         d
# 1               0     0      0            a              1         a
# 2               0     0      0            a              1         a
# 3               0     0      0            a              1         c
# 4               0     0      0            a              1         a
# 5               0     0      0            a              1         c
# 6               0     0      0            a              1         c
# 7               0     0      0            a              1         a
# 8               0     0      0            a              1         a
# 9               0     0      0            a              1         a
# 10              0     0      0            a              1         c
# 11              0     0      0            a              1         d
# 12              0     0      0            a              1         d
# 13              0     0      0            a              1         a
# 14              0     0      0            a              1         d
# 15              0     0      0            a              1         a
# 16              0     0      0            a              1         a
# 17              0     0      0            a              1         a
# 18           1583     1      0            a              1         b
# 19              0     0      0            a              1         a
# 20              0     0      0            a              1         a
# 21              0     0      0            a              1         d
# 22              0     0      0            a              1         c
# 23              0     0      0            a              1         a
# 24              0     0      0            a              1         a
# 25              0     0      0            a              1         a
# 26              0     0      0            a              1         d
# 27              0     0      0            a              1         a
# 28              0     0      0            a              1         d
# 29              0     0      0            a              1         a
# ...           ...   ...    ...          ...            ...       ...
# 372914        616     1      0            0              1         c
# 372915        703     1      0            0              1         a
# 372916        363     1      0            0              1         d
# 372917        376     1      0            0              1         a
# 372918        429     1      0            0              1         d
# 372919        214     1      0            0              1         a
# 372920        599     1      0            0              1         a
# 372921        265     1      0            0              1         d
# 372922        925     1      0            0              1         c
# 372923        672     1      0            0              1         a
# 372924        290     1      0            0              1         d
# 372925        319     1      0            0              1         c
# 372926        363     1      0            0              1         a
# 372927        492     1      0            0              1         d
# 372928        367     1      0            0              1         a
# 372929        473     1      0            0              1         a
# 372930        476     1      0            0              1         d
# 372931        453     1      0            0              1         a
# 372932        609     1      0            0              1         a
# 372933        543     1      0            0              1         a
# 372934        450     1      0            0              1         a
# 372935        462     1      0            0              1         a
# 372936        394     1      0            0              1         a
# 372937        557     1      0            0              1         a
# 372938        308     1      0            0              1         a
# 372939        217     1      0            0              1         a
# 372940       1311     1      0            0              1         c
# 372941        408     1      0            0              1         a
# 372942        252     1      0            0              1         a
# 372943        327     1      0            0              1         c
#
#        Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0               c               5350.0                        NaN
# 1               c                870.0                        NaN
# 2               c               9260.0                        NaN
# 3               c               1880.0                        4.0
# 4               a               1900.0                        6.0
# 5               c                900.0                        9.0
# 6               a               3490.0                        4.0
# 7               a                540.0                        4.0
# 8               a               1400.0                        6.0
# 9               c               5330.0                        9.0
# 10              c                330.0                       11.0
# 11              a                260.0                        2.0
# 12              c               1340.0                       10.0
# 13              a                850.0                       11.0
# 14              c               4060.0                        9.0
# 15              a                540.0                        NaN
# 16              c                200.0                        4.0
# 17              a               1830.0                       11.0
# 18              b                720.0                        3.0
# 19              c               1130.0                        NaN
# 20              a                690.0                        6.0
# 21              a               2380.0                        3.0
# 22              c              10450.0                        6.0
# 23              a                300.0                        7.0
# 24              c               9990.0                        NaN
# 25              a                330.0                        NaN
# 26              a               5220.0                        5.0
# 27              a               4300.0                        3.0
# 28              c               2210.0                       11.0
# 29              a                180.0                       11.0
# ...           ...                  ...                        ...
# 372914          a               2240.0                        9.0
# 372915          c               1320.0                        5.0
# 372916          c               9800.0                        7.0
# 372917          a                 40.0                        2.0
# 372918          c               2170.0                        NaN
# 372919          a               1200.0                       10.0
# 372920          a                 60.0                        1.0
# 372921          a               2300.0                        NaN
# 372922          a                430.0                        4.0
# 372923          c               4590.0                        3.0
# 372924          a               4060.0                        8.0
# 372925          c                550.0                       10.0
# 372926          c               3240.0                        NaN
# 372927          c              13840.0                        6.0
# 372928          a                 50.0                       12.0
# 372929          c               3270.0                        NaN
# 372930          c               4110.0                        3.0
# 372931          a               1300.0                        3.0
# 372932          c               1070.0                        NaN
# 372933          c                960.0                       11.0
# 372934          a               3160.0                        9.0
# 372935          c               2030.0                        8.0
# 372936          a               7520.0                       10.0
# 372937          c              24000.0                        4.0
# 372938          a                310.0                       12.0
# 372939          a              29910.0                        4.0
# 372940          c                620.0                        9.0
# 372941          a              14130.0                       12.0
# 372942          a                570.0                       11.0
# 372943          a               1270.0                        9.0
#
#         CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                            NaN       1             22.0           2012.0
# 1                            NaN       0              NaN              NaN
# 2                            NaN       0              NaN              NaN
# 3                         2006.0       0              NaN              NaN
# 4                         2014.0       1             31.0           2013.0
# 5                         2010.0       0              NaN              NaN
# 6                         2011.0       1             22.0           2012.0
# 7                         2004.0       0              NaN              NaN
# 8                         2012.0       1             13.0           2010.0
# 9                         2011.0       1             31.0           2013.0
# 10                        2008.0       1              5.0           2013.0
# 11                        2012.0       1             14.0           2011.0
# 12                        2006.0       1              5.0           2013.0
# 13                        2012.0       1             40.0           2014.0
# 14                        2012.0       0              NaN              NaN
# 15                           NaN       1             14.0           2011.0
# 16                        2013.0       1             14.0           2013.0
# 17                        2004.0       0              NaN              NaN
# 18                        2002.0       0              NaN              NaN
# 19                           NaN       1             10.0           2014.0
# 20                        2007.0       1             14.0           2011.0
# 21                        2013.0       1             40.0           2014.0
# 22                        2009.0       0              NaN              NaN
# 23                        2000.0       1             40.0           2014.0
# 24                           NaN       0              NaN              NaN
# 25                           NaN       1             14.0           2011.0
# 26                        2009.0       0              NaN              NaN
# 27                        2009.0       1             27.0           2013.0
# 28                        2011.0       0              NaN              NaN
# 29                        2013.0       1             18.0           2011.0
# ...                          ...     ...              ...              ...
# 372914                    2009.0       0              NaN              NaN
# 372915                    2013.0       0              NaN              NaN
# 372916                    2012.0       0              NaN              NaN
# 372917                    2014.0       1             10.0           2014.0
# 372918                       NaN       0              NaN              NaN
# 372919                    2014.0       1              6.0           2015.0
# 372920                    2005.0       1              5.0           2011.0
# 372921                       NaN       0              NaN              NaN
# 372922                    2003.0       0              NaN              NaN
# 372923                    2000.0       1             40.0           2011.0
# 372924                    2005.0       0              NaN              NaN
# 372925                    1999.0       1             45.0           2009.0
# 372926                       NaN       1             22.0           2011.0
# 372927                    2010.0       1             14.0           2012.0
# 372928                    2005.0       1             26.0           2010.0
# 372929                       NaN       0              NaN              NaN
# 372930                    2010.0       1             14.0           2011.0
# 372931                    2014.0       1             40.0           2011.0
# 372932                       NaN       1             13.0           2010.0
# 372933                    2011.0       1              1.0           2012.0
# 372934                    2009.0       0              NaN              NaN
# 372935                    2000.0       0              NaN              NaN
# 372936                    2014.0       0              NaN              NaN
# 372937                    2013.0       0              NaN              NaN
# 372938                    2013.0       0              NaN              NaN
# 372939                    2015.0       0              NaN              NaN
# 372940                    2009.0       0              NaN              NaN
# 372941                    2006.0       1             14.0           2011.0
# 372942                    2007.0       1             13.0           2010.0
# 372943                    2008.0       0              NaN              NaN
#
#            PromoInterval
# 0       Mar,Jun,Sept,Dec
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4        Jan,Apr,Jul,Oct
# 5                    NaN
# 6        Jan,Apr,Jul,Oct
# 7                    NaN
# 8        Jan,Apr,Jul,Oct
# 9        Jan,Apr,Jul,Oct
# 10       Feb,May,Aug,Nov
# 11       Jan,Apr,Jul,Oct
# 12       Feb,May,Aug,Nov
# 13       Jan,Apr,Jul,Oct
# 14                   NaN
# 15       Jan,Apr,Jul,Oct
# 16       Jan,Apr,Jul,Oct
# 17                   NaN
# 18                   NaN
# 19      Mar,Jun,Sept,Dec
# 20       Jan,Apr,Jul,Oct
# 21       Jan,Apr,Jul,Oct
# 22                   NaN
# 23       Jan,Apr,Jul,Oct
# 24                   NaN
# 25       Jan,Apr,Jul,Oct
# 26                   NaN
# 27       Jan,Apr,Jul,Oct
# 28                   NaN
# 29       Feb,May,Aug,Nov
# ...                  ...
# 372914               NaN
# 372915               NaN
# 372916               NaN
# 372917  Mar,Jun,Sept,Dec
# 372918               NaN
# 372919  Mar,Jun,Sept,Dec
# 372920   Jan,Apr,Jul,Oct
# 372921               NaN
# 372922               NaN
# 372923   Jan,Apr,Jul,Oct
# 372924               NaN
# 372925   Jan,Apr,Jul,Oct
# 372926  Mar,Jun,Sept,Dec
# 372927   Jan,Apr,Jul,Oct
# 372928   Jan,Apr,Jul,Oct
# 372929               NaN
# 372930   Jan,Apr,Jul,Oct
# 372931   Jan,Apr,Jul,Oct
# 372932   Jan,Apr,Jul,Oct
# 372933   Jan,Apr,Jul,Oct
# 372934               NaN
# 372935               NaN
# 372936               NaN
# 372937               NaN
# 372938               NaN
# 372939               NaN
# 372940               NaN
# 372941   Jan,Apr,Jul,Oct
# 372942   Jan,Apr,Jul,Oct
# 372943               NaN
#
# [372944 rows x 20 columns]

# %% [markdown]
# ## Plotting functions

# %%
#catplot
def cat(x, y, df, k):
    sns.catplot(x,y,data=df, kind = k)

#catplot of larger size
def big_cat(x, y, df, k):
    fig, ax = plt.subplots(1, 1, figsize=(8, 6))
    sns.catplot(ax = ax, x = x, y = y, data=df, kind = k)
    plt.close(2)
    plt.show()
    
#date specific plotting
def dateplot(x, y, df, k):
    fig, ax = plt.subplots(1, 1, figsize=(80, 18))
    sns.catplot(ax = ax, x = x, y = y, data=df, kind = k)
    plt.close(2)
    plt.show()

# %% [markdown]
# ## StoreType vs Sales

# %% [markdown]
# This function provides access to several axes-level functions that show the relationship between a numerical and one or more categorical variables using one of several visual representations.

# %%
cat("StoreType","Sales", q1, 'strip')
# cat("StoreType","Sales", q2, 'strip')
# cat("StoreType","Sales", q3, 'strip')
# cat("StoreType","Sales", q4, 'strip')

# %%
cat("StoreType", "Sales", q1, "boxen")

# %%
cat("StoreType", "Sales", q1, "box")

# %% [markdown]
# ## WeekDay vs Sales

# %%
cat("DayOfWeek","Sales", q2, "bar")

# %%
big_cat("DayOfWeekName","Sales", q4, "strip")

# %%
big_cat("DayOfWeekName","Sales", q4, "bar")

# %%
big_cat("DayOfWeekName","Sales", q4, "point")

# %% [markdown]
# ## Month vs Sales

# %%
cat("MonthName","Sales",df_new, "bar")

# %%
cat("MonthName", "Sales", q1, "bar")

# %%
cat("MonthName", "Sales", q2, "bar")

# %%
cat("MonthName", "Sales", q3, "bar")

# %%
cat("MonthName", "Sales", q4, "bar")

# %% [markdown]
# ## Customers vs StoreType

# %%
cat("StoreType", "Customers", q1, "bar")

# %% [markdown]
# ## Date vs Sales

# %%
# In this subtopic, the store sales are need to be added according to their respective dates for all quarter datasets
df = pd.DataFrame(columns = ['Date', 'Sales'])
date_sum = 0
for i in range(len(q4)):
    if q4.iloc[i]['Date'] == q4.iloc[i-1]['Date'] and i>= 1:
        date_sum += q4.iloc[i]['Sales']
        
    else:
        if i!=0:
            df = df.append(pd.DataFrame([[q4.iloc[i-1]['Date'], date_sum]], columns = ['Date', 'Sales']), ignore_index=True)
            print(q4.iloc[i-1]['Date'], ":", date_sum)
        date_sum = 0 + q4.iloc[i]['Sales']
        
# adding month label
pd.DatetimeIndex(q4_datesales['Date']).month
q4_datesales.insert(2, 'MonthName', pd.DataFrame([int(q4_datesales['Date'][i][5:7]) for i in q4_datesales.index]))
q4_datesales['MonthName'] = q4_datesales['MonthName'].apply(lambda x: calendar.month_abbr[x])
        
# saving to csv
df = df.append(pd.DataFrame([[q4.iloc[i]['Date'], date_sum]], columns = ['Date', 'Sales']), ignore_index=True)
df.to_csv(r"D:\Devansh\ML\Datasets\Rossman_Store_Sales(Regression)\quarters\q4_datesales.csv", index= False)

# %%
q4_datesales
# Out:
#           Date     Sales MonthName
# 0   2014-04-01   9114237       Apr
# 1   2014-04-02   8314447       Apr
# 2   2014-04-03   8215262       Apr
# 3   2014-04-04   8575005       Apr
# 4   2014-04-05   6560749       Apr
# 5   2014-04-06    223163       Apr
# 6   2014-04-07   6624706       Apr
# 7   2014-04-08   6248167       Apr
# 8   2014-04-09   6410230       Apr
# 9   2014-04-10   6524511       Apr
# 10  2014-04-11   6910251       Apr
# 11  2014-04-12   6388099       Apr
# 12  2014-04-13    241475       Apr
# 13  2014-04-14  11683139       Apr
# 14  2014-04-15  10668363       Apr
# 15  2014-04-16  10024850       Apr
# 16  2014-04-17  10357418       Apr
# 17  2014-04-18    222365       Apr
# 18  2014-04-19   8428009       Apr
# 19  2014-04-20    186799       Apr
# 20  2014-04-21    240988       Apr
# 21  2014-04-22   6971756       Apr
# 22  2014-04-23   5997676       Apr
# 23  2014-04-24   6039156       Apr
# 24  2014-04-25   6219955       Apr
# 25  2014-04-26   5968493       Apr
# 26  2014-04-27    219630       Apr
# 27  2014-04-28  10667908       Apr
# 28  2014-04-29   9457130       Apr
# 29  2014-04-30  10841040       Apr
# ..         ...       ...       ...
# 61  2014-06-01    264670       Jun
# 62  2014-06-02  11662688       Jun
# 63  2014-06-03   9598519       Jun
# 64  2014-06-04   8807342       Jun
# 65  2014-06-05   8812312       Jun
# 66  2014-06-06   8857173       Jun
# 67  2014-06-07   6731210       Jun
# 68  2014-06-08    275989       Jun
# 69  2014-06-09    288181       Jun
# 70  2014-06-10   7416071       Jun
# 71  2014-06-11   6688764       Jun
# 72  2014-06-12   6939204       Jun
# 73  2014-06-13   7068339       Jun
# 74  2014-06-14   6574173       Jun
# 75  2014-06-15    238273       Jun
# 76  2014-06-16  10692037       Jun
# 77  2014-06-17   9295150       Jun
# 78  2014-06-18   9059505       Jun
# 79  2014-06-19   3307766       Jun
# 80  2014-06-20   9683407       Jun
# 81  2014-06-21   6065789       Jun
# 82  2014-06-22    230668       Jun
# 83  2014-06-23   6604967       Jun
# 84  2014-06-24   6040970       Jun
# 85  2014-06-25   5977803       Jun
# 86  2014-06-26   5802491       Jun
# 87  2014-06-27   6910940       Jun
# 88  2014-06-28   6586535       Jun
# 89  2014-06-29    257513       Jun
# 90  2014-06-30  13308602       Jun
#
# [91 rows x 3 columns]

# %%
#applying text formatting for clear labels and subgrouping each 5 dates for clear distribution of graph bins
df = pd.DataFrame(columns = ['Date', 'Sales'])
count = 0
date_sum = 0

for i in range(len(q4_datesales)):
    if count == 4 or i== len(q4_datesales)-1:
        count = 0
        date_sum += q3_datesales.iloc[i]['Sales']
        
        bins = q4_datesales.iloc[i-4]['Date'][-2:] + '-' + str(q4_datesales.iloc[i]['Date'][-2:]) + ' ' + str(q4_datesales.iloc[i]['MonthName']) 
        
        df = df.append(pd.DataFrame([[bins, date_sum]], 
                                    columns = ['Date', 'Sales']), ignore_index=True)
        print(bins, ":", date_sum)
        date_sum = 0
        
    else:
        date_sum += q4_datesales.iloc[i]['Sales']
        count += 1

df.to_csv(r"D:\Devansh\ML\Datasets\Rossman_Store_Sales(Regression)\quarters\q4_datesales5.csv", index= False)
# Out:
# 01-05 Oct : 27969381
# 06-10 Oct : 35777295
# 11-15 Oct : 23775334
# 16-20 Oct : 16027948
# 21-25 Oct : 31287520
# 26-30 Oct : 23645133
# 31-04 Nov : 28859091
# 05-09 Nov : 32543689
# 10-14 Nov : 34010010
# 15-19 Nov : 24695603
# 20-24 Nov : 17362055
# 25-29 Nov : 38990031
# 30-04 Dec : 34791013
# 05-09 Dec : 28693043
# 10-14 Dec : 30481752
# 15-19 Dec : 48443516
# 20-24 Dec : 34912546
# 25-29 Dec : 6509629
# 27-31 Dec : 16559531

# %%
q1_datesales5
# Out:
#          Date     Sales
# 0   01-05 Jan  20665081
# 1   06-10 Jan  44327212
# 2   11-15 Jan  24062120
# 3   16-20 Jan  29090519
# 4   21-25 Jan  37909075
# 5   26-30 Jan  23762927
# 6   31-04 Feb  36494175
# 7   05-09 Feb  31336500
# 8   10-14 Feb  31821757
# 9   15-19 Feb  33723375
# 10  20-24 Feb  27946091
# 11  25-01 Mar  32627589
# 12  02-06 Mar  36939794
# 13  07-11 Mar  26860124
# 14  12-16 Mar  24664759
# 15  17-21 Mar  41449071
# 16  22-26 Mar  24651559
# 17  27-31 Mar  31365590

# %%
dateplot("Date", "Sales", q1_datesales5, "point")

# %%
dateplot("Date", "Sales", q2_datesales5, "point")

# %%
dateplot("Date", "Sales", q3_datesales5, "point")

# %%
dateplot("Date", "Sales", q4_datesales5, "point")
